# %% [markdown]
# # PROGRAM DESCRIPTION:
#     prompt user for a stock ticker symbol, then print out going back in time when stock was above or below SMA

# %%
import pandas as pd
import numpy as np
import yfinance as yf
import datetime as dt 
from pandas_datareader import data as pdr

# %%
yf.pdr_override()

# %%
df=yf.download(['AAPL'],period= '3Y')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
df.head()
# Out:
#                                 Open       High        Low      Close  \
# Date
# 2020-04-22 00:00:00-04:00  68.402496  69.474998  68.050003  69.025002
# 2020-04-23 00:00:00-04:00  68.967499  70.437500  68.717499  68.757500
# 2020-04-24 00:00:00-04:00  69.300003  70.752502  69.250000  70.742500
# 2020-04-27 00:00:00-04:00  70.449997  71.135002  69.987503  70.792503
# 2020-04-28 00:00:00-04:00  71.269997  71.457497  69.550003  69.644997
#
#                            Adj Close     Volume
# Date
# 2020-04-22 00:00:00-04:00  67.679390  116862400
# 2020-04-23 00:00:00-04:00  67.417114  124814400
# 2020-04-24 00:00:00-04:00  69.363396  126161200
# 2020-04-27 00:00:00-04:00  69.412437  117087600
# 2020-04-28 00:00:00-04:00  68.287300  112004800

# %% [markdown]
# creating a sma column

# %%
df[smaString]= df.iloc[:,4].rolling(ma).mean()
# Out:
# C:\Users\aheed\AppData\Local\Temp\ipykernel_15708\2745420653.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[smaString]= df.iloc[:,4].rolling(ma).mean()

# %%
print(df.tail())
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2023-04-17 00:00:00-04:00  165.089996  165.389999  164.029999  165.229996
# 2023-04-18 00:00:00-04:00  166.100006  167.410004  165.649994  166.470001
# 2023-04-19 00:00:00-04:00  165.800003  168.160004  165.539993  167.630005
# 2023-04-20 00:00:00-04:00  166.089996  167.869995  165.559998  166.649994
# 2023-04-21 00:00:00-04:00  165.050003  166.449997  164.490005  165.020004
#
#                             Adj Close    Volume       Sma50
# Date
# 2023-04-17 00:00:00-04:00  165.229996  41516200  155.486516
# 2023-04-18 00:00:00-04:00  166.470001  49923000  155.730627
# 2023-04-19 00:00:00-04:00  167.630005  47720200  156.053253
# 2023-04-20 00:00:00-04:00  166.649994  52456400  156.297968
# 2023-04-21 00:00:00-04:00  165.020004  58311900  156.564600

# %% [markdown]
# removing nan values and starting from days we get first moving average, since its 50 days we get first sma at day 50 and that is where we begin our index from

# %%
df=df.iloc[ma:]

# %%
df.head()
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2020-11-23 00:00:00-05:00  117.180000  117.620003  113.750000  113.849998
# 2020-11-24 00:00:00-05:00  113.910004  115.849998  112.589996  115.169998
# 2020-11-25 00:00:00-05:00  115.550003  116.750000  115.169998  116.029999
# 2020-11-27 00:00:00-05:00  116.570000  117.489998  116.220001  116.589996
# 2020-11-30 00:00:00-05:00  116.970001  120.970001  116.809998  119.050003
#
#                             Adj Close     Volume       Sma50
# Date
# 2020-11-23 00:00:00-05:00  112.328003  127959300  113.709138
# 2020-11-24 00:00:00-05:00  113.630363  113874200  113.705764
# 2020-11-25 00:00:00-05:00  114.478851   76499200  113.786532
# 2020-11-27 00:00:00-05:00  115.031387   46691300  113.913610
# 2020-11-30 00:00:00-05:00  117.458496  169410200  114.158177

# %%
df['Sma50']
# Out:
# Date
# 2020-11-23 00:00:00-05:00    113.709138
# 2020-11-24 00:00:00-05:00    113.705764
# 2020-11-25 00:00:00-05:00    113.786532
# 2020-11-27 00:00:00-05:00    113.913610
# 2020-11-30 00:00:00-05:00    114.158177
#                                 ...
# 2023-04-17 00:00:00-04:00    155.486516
# 2023-04-18 00:00:00-04:00    155.730627
# 2023-04-19 00:00:00-04:00    156.053253
# 2023-04-20 00:00:00-04:00    156.297968
# 2023-04-21 00:00:00-04:00    156.564600
# Name: Sma50, Length: 606, dtype: float64

# %%
for i in df.index:
    if (df['Adj Close'][i]>df['Sma50'][i]):
        print ("The Close is Higher")
    else:
        print ('The Close is Lower')
# Out:
# The Close is Lower
# The Close is Lower
# The Close is Higher
# The Close is Higher
# The Close is Higher
# The Close is Higher
# The Close is Higher
# The Close is Higher
# The Close is Higher
# The Close is Higher
# The Close is Higher
# The Close is Higher
# The Close is Higher
# The Close is Higher
# The Close is Higher
# The Close is Higher
# The Close is Higher
# The Close is Higher
# The Close is Higher
# The Close is Higher
# The Close is Higher
# The Close is Higher
# The Close is Higher
# The Close is Higher
# The Close is Higher
# The Close is Higher
# The Close is Higher
# The Close is Higher
# The Close is Higher
# The Close is Higher
# The Close is Higher
# The Close is Higher
# The Close is Higher
# The Close is Higher
# The Close is Higher
# The Close is Higher
# The Close is Higher
# The Close is Higher
# The Close is Higher
# The Close is Higher
# The Close is Higher
# The Close is Higher
# The Close is Higher
# The Close is Higher
# The Close is Higher
# ...

# %%
def stock_sma_checker():
    numh=0
    numl=0
    df=yf.download(['META'],period= '1Y')
    df['Sma50']= df.iloc[:,4].rolling(ma).mean()
    df=df.iloc[ma:]

    for i in df.index:
        if (df['Adj Close'][i]>df['Sma50'][i]):
            print ("The Close is Higher")
            numh+=1
        else:
            print ('The Close is Lower')
            numl+=1
    print('Number of close being higher than Sma: ' + str(numh))
    print('Number of close being lower than Sma: ' + str(numl))

stock_sma_checker()
# Out:
# [*********************100%***********************]  1 of 1 completed
# The Close is Lower
# The Close is Lower
# The Close is Lower
# The Close is Lower
# The Close is Lower
# The Close is Lower
# The Close is Lower
# The Close is Lower
# The Close is Lower
# The Close is Lower
# The Close is Higher
# The Close is Higher
# The Close is Lower
# The Close is Lower
# The Close is Lower
# The Close is Lower
# The Close is Lower
# The Close is Lower
# The Close is Lower
# The Close is Lower
# The Close is Lower
# The Close is Lower
# The Close is Lower
# The Close is Lower
# The Close is Lower
# The Close is Higher
# The Close is Higher
# The Close is Higher
# The Close is Higher
# The Close is Higher
# The Close is Higher
# The Close is Higher
# The Close is Lower
# The Close is Lower
# The Close is Lower
# The Close is Lower
# The Close is Higher
# The Close is Lower
# The Close is Lower
# The Close is Lower
# The Close is Lower
# The Close is Lower
# The Close is Lower
# ...
