# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mlt
import yfinance as yf
# %matplotlib inline

from pandas_datareader import data as wb

# %%
tickers= yf.download(['^GSPC','^IXIC','^GDAXI','^FTSE'],period= '20Y')['Adj Close']
# Out:
# [*********************100%***********************]  4 of 4 completed

# %%
tickers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 19702 entries, 1997-04-10 22:00:00+00:00 to 2023-04-11 04:00:00+00:00
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ^FTSE   6566 non-null   float64
#  1   ^GDAXI  6594 non-null   float64
#  2   ^GSPC   6542 non-null   float64
#  3   ^IXIC   6542 non-null   float64
# dtypes: float64(4)
# memory usage: 769.6 KB

# %%
tickers.head()
# Out:
#                                  ^FTSE       ^GDAXI      ^GSPC        ^IXIC
# Date
# 2003-04-10 22:00:00+00:00          NaN  2733.949951        NaN          NaN
# 2003-04-10 23:00:00+00:00  3808.100098          NaN        NaN          NaN
# 2003-04-13 22:00:00+00:00          NaN  2776.780029        NaN          NaN
# 2003-04-13 23:00:00+00:00  3849.399902          NaN        NaN          NaN
# 2003-04-14 04:00:00+00:00          NaN          NaN  885.22998  1384.949951

# %%
tickers= yf.download(['^GSPC','^IXIC','^GDAXI','^FTSE'],period= '20Y')['Adj Close']
tickers.head()
# Out:
# [*********************100%***********************]  4 of 4 completed
#                                  ^FTSE       ^GDAXI      ^GSPC        ^IXIC
# Date
# 2003-04-10 22:00:00+00:00          NaN  2733.949951        NaN          NaN
# 2003-04-10 23:00:00+00:00  3808.100098          NaN        NaN          NaN
# 2003-04-13 22:00:00+00:00          NaN  2776.780029        NaN          NaN
# 2003-04-13 23:00:00+00:00  3849.399902          NaN        NaN          NaN
# 2003-04-14 04:00:00+00:00          NaN          NaN  885.22998  1384.949951

# %%
pg= yf.download(['^GSPC','PG','^DJI'],period= '20Y')['Adj Close']

# %%
tickers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 757 entries, 2022-04-10 22:00:00+00:00 to 2023-04-11 04:00:00+00:00
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ^FTSE   250 non-null    float64
#  1   ^GDAXI  257 non-null    float64
#  2   ^GSPC   250 non-null    float64
#  3   ^IXIC   250 non-null    float64
# dtypes: float64(4)
# memory usage: 29.6 KB

# %%
tickers.to_csv('D:\\BURAIR\\tickers.csv')

# %% [markdown]
# # normalising to 100 and graphing, 1 starting point

# %%
indices= pd.read_csv('D:\\BURAIR\\index.csv',index_col='Date')
indices.head()
# Out:
#                  ^GSPC        ^IXIC       ^GDAXI        ^FTSE
# Date
# 31/12/1996  740.739990  1291.030029          NaN  4118.500000
# 02/01/1997  737.010010  1280.699951  2820.810059  4057.399902
# 03/01/1997  748.030029  1310.680054  2863.260010  4089.500000
# 06/01/1997  747.650024  1316.400024  2890.199951  4106.500000
# 07/01/1997  753.229980  1327.729980  2876.340088  4078.800049

# %%
(indices/indices.iloc[1]*100).plot(figsize=(15,6))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# Out:
# [*********************100%***********************]  3 of 3 completed

# %%
(pg/pg.iloc[0]*100).plot(figsize=(15,6))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
pg.head()
# Out:
#                                   PG         ^DJI       ^GSPC
# Date
# 2003-04-14 00:00:00-04:00  26.101126  8351.099609  885.229980
# 2003-04-15 00:00:00-04:00  26.200243  8402.360352  890.809998
# 2003-04-16 00:00:00-04:00  25.972883  8257.610352  879.909973
# 2003-04-17 00:00:00-04:00  26.019512  8337.650391  893.580017
# 2003-04-21 00:00:00-04:00  26.069075  8328.900391  892.010010

# %%
gd= yf.download(['^GDAXI'],period= '20Y')['Adj Close']
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
(gd/gd.iloc[0]*100).plot(figsize=(15,6))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
returns= (tickers/tickers.shift(1))-1

# %%
returns.tail()
# Out:
#                            ^FTSE  ^GDAXI     ^GSPC     ^IXIC
# Date
# 2023-04-06 04:00:00+00:00    NaN     NaN       NaN       NaN
# 2023-04-10 04:00:00+00:00    NaN     NaN  0.000996 -0.000298
# 2023-04-10 22:00:00+00:00    NaN     NaN       NaN       NaN
# 2023-04-10 23:00:00+00:00    NaN     NaN       NaN       NaN
# 2023-04-11 04:00:00+00:00    NaN     NaN       NaN       NaN

# %%
annual= returns.mean()*250
annual
# Out:
# ^FTSE          NaN
# ^GDAXI    0.629750
# ^GSPC     0.620685
# ^IXIC     0.889036
# dtype: float64

# %%
aa= yf.download(['AAPL','^GSPC','^DJI'], period='20Y')['Adj Close']
aa.head()
# Out:
# [*********************100%***********************]  3 of 3 completed
#                                AAPL         ^DJI       ^GSPC
# Date
# 2003-04-14 00:00:00-04:00  0.206396  8351.099609  885.229980
# 2003-04-15 00:00:00-04:00  0.203508  8402.360352  890.809998
# 2003-04-16 00:00:00-04:00  0.201229  8257.610352  879.909973
# 2003-04-17 00:00:00-04:00  0.199405  8337.650391  893.580017
# 2003-04-21 00:00:00-04:00  0.199709  8328.900391  892.010010

# %%
(aa/aa.iloc[0]*100).plot(figsize=(15,6))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
aa.tail()
# Out:
#                                  AAPL          ^DJI        ^GSPC
# Date
# 2023-04-04 00:00:00-04:00  165.630005  33402.378906  4100.600098
# 2023-04-05 00:00:00-04:00  163.759995  33482.718750  4090.379883
# 2023-04-06 00:00:00-04:00  164.660004  33485.289062  4105.020020
# 2023-04-10 00:00:00-04:00  162.029999  33586.519531  4109.109863
# 2023-04-11 00:00:00-04:00  160.800003  33684.789062  4108.939941

# %%
areturns= (aa/aa.shift(1))-1

# %%
aannual= areturns.mean()*250
aannual
# Out:
# AAPL     0.387022
# ^DJI     0.085734
# ^GSPC    0.094556
# dtype: float64

# %%
(indices/indices.iloc[1]*100).plot(figsize=(15,6))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
(tickers/tickers.iloc[10]*100).plot(figsize=(15,6))
# Out:
# <AxesSubplot:xlabel='Date'>
