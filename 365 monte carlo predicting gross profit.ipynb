# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
rev_m=170
rev_std=20
iterations = 1000

# %% [markdown]
# task: predict future gross profit
# required: cogs, exp revenue
# perform 1000 simulations of exp revenue
# you have an idea about rev growth rate and exp rev for this year is 170 mil and std is 20 mil

# %%
rev=np.random.normal(rev_m,rev_std,iterations)

# %%
rev
# Out:
# array([158.82191368, 193.44709555, 165.32408779, 158.37909909,
#        161.94703418, 190.52545057, 162.88461789, 183.4942416 ,
#        210.17080511, 187.86507419, 157.79708255, 152.33389153,
#        174.06877826, 133.21631386, 157.91773733, 169.43705226,
#        197.74962026, 167.7541608 , 201.86909803, 194.76381504,
#        147.26176144, 156.15263975, 167.21116799, 163.59213766,
#        158.41958925, 181.85279614, 201.98043859, 167.85221298,
#        149.07136512, 145.07276891, 212.14860168, 167.71794508,
#        171.52401423, 169.59707303, 171.40268626, 167.97636394,
#        182.537194  , 167.17428648, 170.01702484, 212.33790444,
#        167.7091826 , 161.76335274, 209.96204002, 180.3896596 ,
#        199.31369367, 178.11828938, 189.98423909, 168.16676423,
#        187.85107987, 168.25954202, 156.90690329, 129.89266365,
#        171.11282192, 165.68420876, 194.33290556, 124.25064412,
#        177.5180744 , 162.08288361, 200.80202786, 174.21371181,
# ...

# %%
plt.figure(figsize=(15,6))
plt.plot(rev)
plt.show()

# %% [markdown]
# assume cogs is 60% (mean of prev cogs) with std of 10% of rev based on previous data

# %%
cogs= - (rev*np.random.normal(0.6,0.1))

plt.figure(figsize=(15,6))
plt.plot(cogs)
plt.show()

# %%
cogs.mean()
# Out:
# -95.78171377410294

# %%
cogs.std()
# Out:
# 11.397450181218678

# %%
grossp = rev+ cogs
grossp

plt.figure(figsize=(15,6))
plt.plot(grossp)
plt.show()

# %%
max(grossp)
# Out:
# 100.11427529562826

# %%
min(grossp)
# Out:
# 45.35851534455041

# %%
grossp.mean()
# Out:
# 73.92316457955967

# %%
grossp.std()
# Out:
# 8.796413765582068

# %%
plt.figure(figsize=(10,6));
plt.hist(grossp, bins = [40,50,60,70,80,90,100,110,120])
plt.show()

# %%
plt.figure(figsize=(10,6));
plt.hist(grossp, bins = 20)
plt.show()
#python distributes data in 20 equal intervals thru no of bins
